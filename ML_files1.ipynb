# %%
import pandas as pd

# %%
df=pd.read_csv("/content/ShelterDogs.csv")
df # As dataframe has supervised ML
# Out:
#          ID            name    age     sex                           breed  \
# 0     23807            Gida   0.25  female                     Unknown Mix
# 1       533  Frida És Ricsi   0.17  female                     Unknown Mix
# 2     23793             NaN   4.00    male                     Unknown Mix
# 3     23795             NaN   1.00    male                     Unknown Mix
# 4     23806             Amy   2.00  female              French Bulldog Mix
# ...     ...             ...    ...     ...                             ...
# 2932    118           Fodri  16.92    male                     Unknown Mix
# 2933    262           Csibi  17.33  female       Staffordshire Terrier Mix
# 2934      4          Konrád  18.17    male                     Unknown Mix
# 2935    141           Kölni  17.17    male                     Unknown Mix
# 2936    248          Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
# ...

# %%
df2=pd.read_csv("/content/browser_version.csv")
df2  # As DataFrame has supervised ML
# Out:
#         Date  Chrome for Android  IE 8.0  Safari iPhone  Firefox 3.6  IE 9.0  \
# 0    2009-01                0.00    0.88           0.15          0.0    0.00
# 1    2009-02                0.00    1.17           0.16          0.0    0.00
# 2    2009-03                0.00    1.71           0.19          0.0    0.00
# 3    2009-04                0.00    3.63           0.21          0.0    0.00
# 4    2009-05                0.00    6.24           0.19          0.0    0.00
# ..       ...                 ...     ...            ...          ...     ...
# 158  2022-03               36.17    0.02          13.98          0.0    0.03
# 159  2022-04               37.75    0.02          14.43          0.0    0.03
# 160  2022-05               38.79    0.01          14.59          0.0    0.03
# 161  2022-06               39.82    0.01          14.38          0.0    0.02
# 162  2022-07               40.29    0.01          14.70          0.0    0.03
#
# ...

# %%
df3=pd.read_csv("/content/Top vendors market share (2022 Q1).csv")
df3 # As DataFrame has a supervised ML
# Out:
#    Rank Manufacturer Market share
# 0     1       Lenovo       23.80%
# 1     2           HP       20.40%
# 2     3         Dell       17.70%
# 3     4        Apple        9.00%
# 4     5         Acer        7.20%
# 5     6         Asus        7.10%
# 6     7       Others       14.80%

# %%
df4=pd.read_csv("/content/Worldwide personal computer architectures by units sold (19751995).csv")
df4  # As DataFrame has an unsupervised ML
# Out:
#           Year Annual sales IBM PC compatible   Apple II   Macintosh  \
# 0         1975        5,000                 0          0           0
# 1         1976       46,000                 0          0           0
# 2         1977      150,000                 0        600           0
# 3         1978      258,000                 0      7,600           0
# 4         1979      580,000                 0     35,000           0
# 5         1980      724,000                 0     78,000           0
# 6         1981    1,400,000            35,000    210,000           0
# 7         1982    2,800,000           240,000    279,000           0
# 8         1983    4,920,000         1,300,000    420,000           0
# 9         1984    6,322,000         2,000,000  1,000,000     372,000
# 10        1985    7,610,000         3,700,000    900,000     200,000
# 11        1986    9,000,000         5,020,000    700,000     380,000
# 12        1987    9,200,000         5,950,000    500,000     550,000
# ...

# %%
df5=pd.read_csv("/content/Mall_Customers.csv")
df5  # As DataFrame has supervised ML
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df6=pd.read_csv("/content/financials.csv")
df6  #  As DataFrame has an unsupervised
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df7=pd.read_csv("/content/National_Stock_Exchange_of_India_Ltd.csv")
df7  # As DataFrame has an unsupervised
# Out:
#         Symbol       Open       High        Low        LTP    Chng  % Chng  \
# 0   ADANIPORTS        750        766     713.25        715  -47.45   -6.22
# 1   ASIANPAINT   3,101.00   3,167.35   3,091.00   3,138.00   -6.25   -0.20
# 2     AXISBANK        669      674.9     660.45        661  -18.90   -2.78
# 3   BAJAJ-AUTO   3,370.00   3,383.50   3,320.00   3,335.00  -56.70   -1.67
# 4   BAJAJFINSV  17,200.00  17,237.20  16,610.00  16,684.00 -684.85   -3.94
# 5   BAJFINANCE   7,021.00   7,047.90   6,775.00   6,780.00 -345.80   -4.85
# 6   BHARTIARTL        763        763      733.1     735.85  -29.30   -3.83
# 7         BPCL     397.15      397.2        375      377.4  -22.70   -5.67
# 8    BRITANNIA   3,560.00   3,635.10   3,533.95   3,566.60   -6.80   -0.19
# 9        CIPLA        892     976.05     890.65        965   65.05    7.23
# 10   COALINDIA     157.75      159.4     155.35      155.9   -2.65   -1.67
# ...

# %%
df8=pd.read_csv("/content/KnowledgeBase Pdf Files - Crypto Currencies.csv")
df8   #As DataFrame has supervised
# Out:
#                                                 Topic  \
# 0   The impact of the Russian-Ukrainian war on glo...
# 1   Information in Financial Markets and Its Real ...
# 2                             Taxing cryptocurrencies
# 3   Cryptocurrencies: market analysis and perspect...
# 4          A Statistical Analysis of Cryptocurrencies
# 5   Privacy-Preserving Multi-Party Cross-Chain Tra...
# 6   Unveiling Cryptocurrency Impact on Financial M...
# 7   Decentralization Is Good or Not? Defending Con...
# 8   Review of Blockchain’s Role in E-Commerce Tran...
# 9   Time Series Forecasting Utilizing Automated Ma...
# 10  Is Monetary Policy a Driver of Cryptocurrencie...
# 11  Time-Varying Bidirectional Causal Relationship...
# 12  Blockchain Architectures for the Digital Econo...
# 13  Blockchain-Powered Gaming: Bridging Entertainm...
# 14  Unveiling the Influencing Factors of Cryptocur...
# 15  Using Machine Learning of Artificial Intellige...
# ...

# %%
df9=pd.read_csv("/content/jobs_in_data.csv")
df9
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df10=pd.read_csv("/content/final_data.csv")
df10  # As dataframe has unsupervised ML.
# Out:
#     Company_Name    Class                                        Designation  \
# 0          Wipro  Class 3                                    Project Manager
# 1          Wipro  Class 3                                    Project Manager
# 2          Wipro  Class 3                                    Project Manager
# 3          Wipro  Class 3                                      Administrator
# 4          Wipro  Class 3                                    Project Manager
# ..           ...      ...                                                ...
# 806      Infosys  Class 3                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Class 3  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact  Class 1                             Hiring for OTC- JAIPUR
# 809      Genpact  Class 1                                      C++ Developer
# 810      Genpact  Class 1                             Hiring for RTR- Jaipur
#
# ...
